# %%
pip install kagglehub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting kagglehub
#   Using cached kagglehub-0.3.12-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in c:\users\prade\appdata\roaming\python\python313\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\prade\appdata\roaming\python\python313\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\prade\appdata\roaming\python\python313\site-packages (from kagglehub) (2.32.4)
# Collecting tqdm (from kagglehub)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\prade\appdata\roaming\python\python313\site-packages (from requests->kagglehub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prade\appdata\roaming\python\python313\site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prade\appdata\roaming\python\python313\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prade\appdata\roaming\python\python313\site-packages (from requests->kagglehub) (2025.8.3)
# Requirement already satisfied: colorama in c:\users\prade\appdata\roaming\python\python313\site-packages (from tqdm->kagglehub) (0.4.6)
# Using cached kagglehub-0.3.12-py3-none-any.whl (67 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, kagglehub
#
#    ---------------------------------------- 0/2 [tqdm]
#    ---------------------------------------- 0/2 [tqdm]
#    ---------------------------------------- 0/2 [tqdm]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    ---------------------------------------- 2/2 [kagglehub]
#
# Successfully installed kagglehub-0.3.12 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\users\prade\appdata\roaming\python\python313\site-packages (25.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\prade\appdata\roaming\python\python313\site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\prade\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
# path = kagglehub.dataset_download("kmader/skin-cancer-mnist-ham10000")

# print("Path to dataset files:", path)

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prade\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\prade\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ----------------------------- ---------- 8.1/11.0 MB 45.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 31.0 MB/s  0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed pandas-2.3.1 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import os

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
from glob import glob

# %%
from PIL import Image

# %%
print(kagglehub.__version__)
print(pd.__version__)
#print(os.version)
#print(glob.__version__)
print(Image.__version__)
print(matplotlib.__version__)
# Out:
# 0.3.12
# 2.3.1
# 11.3.0
# 3.10.5

# %%
skin_df = pd.read_csv("HAM10000_dataset/HAM10000_metadata.csv")

# %%
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
# image_path = {os.path.splitext(os.path.basename(x))[0]: x
#                for x in glob(os.path.join('HAM10000_dataset/', '*', '*.jpg'))}

# %%
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
# skin_df['path'] = skin_df['image_id'].map(image_path.get)

# %%
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
# skin_df['image'] = skin_df['path'].map(lambda x: np.asarray(Image.open(x).resize((32,32))))

# %%
# print(skin_df['dx'].value_counts())

# %%
import shutil

# %%
data_dir = os.getcwd() + "/HAM10000_dataset/All_images/"

# %%
dest_dir = os.getcwd() + "/HAM10000_dataset/recognised/"

# %%
skin_df2 = pd.read_csv('HAM10000_dataset/HAM10000_metadata.csv')

# %%
skin_df2
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
print(skin_df2['dx'].value_counts())
# Out:
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64

# %%
label = skin_df2['dx'].unique().tolist()

# %%
label_images = []

# %%
pip install torch --index-url https://download.pytorch.org/whl/cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.8.0%2Bcpu-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Collecting filelock (from torch)
#   Downloading https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from torch) (4.14.1)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in c:\users\prade\appdata\roaming\python\python313\site-packages (from torch) (3.1.6)
# Collecting fsspec (from torch)
#   Downloading https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in c:\users\prade\appdata\roaming\python\python313\site-packages (from torch) (80.9.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#      ---------------------------------------- 536.2/536.2 kB 11.4 MB/s  0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.8.0%2Bcpu-cp313-cp313-win_amd64.whl (619.4 MB)
#    ---------------------------------------- 0.0/619.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/619.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/619.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/619.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/619.4 MB ? eta -:--:--
#    ---------------------------------------- 0.5/619.4 MB 1.1 MB/s eta 0:09:02
#    ---------------------------------------- 1.6/619.4 MB 2.6 MB/s eta 0:03:59
#    ---------------------------------------- 3.1/619.4 MB 4.0 MB/s eta 0:02:35
#    ---------------------------------------- 6.6/619.4 MB 6.4 MB/s eta 0:01:36
#     --------------------------------------- 10.2/619.4 MB 8.1 MB/s eta 0:01:16
#     --------------------------------------- 13.6/619.4 MB 9.2 MB/s eta 0:01:06
#    - -------------------------------------- 15.7/619.4 MB 9.4 MB/s eta 0:01:05
#    - -------------------------------------- 17.8/619.4 MB 9.5 MB/s eta 0:01:04
#    - -------------------------------------- 21.5/619.4 MB 11.0 MB/s eta 0:00:55
#    - -------------------------------------- 24.9/619.4 MB 11.5 MB/s eta 0:00:52
#    - -------------------------------------- 28.8/619.4 MB 11.9 MB/s eta 0:00:50
#    -- ------------------------------------- 33.0/619.4 MB 12.4 MB/s eta 0:00:48
#    --------- ------------------------------ 78.9/332.0 MB 6.0 MB/s eta 0:00:43
#    --------- ------------------------------ 79.2/332.0 MB 5.8 MB/s eta 0:00:44
#    --------- ------------------------------ 79.7/332.0 MB 5.7 MB/s eta 0:00:45
#    --------- ------------------------------ 80.2/332.0 MB 5.7 MB/s eta 0:00:45
#    --------- ------------------------------ 82.3/332.0 MB 5.7 MB/s eta 0:00:44
#    ---------- ----------------------------- 86.0/332.0 MB 5.9 MB/s eta 0:00:42
#    ---------- ----------------------------- 87.3/332.0 MB 5.9 MB/s eta 0:00:42
#    ---------- ----------------------------- 88.6/332.0 MB 5.9 MB/s eta 0:00:42
#    ---------- ----------------------------- 89.4/332.0 MB 5.9 MB/s eta 0:00:42
#    ---------- ----------------------------- 89.4/332.0 MB 5.9 MB/s eta 0:00:42
#    ---------- ----------------------------- 89.4/332.0 MB 5.9 MB/s eta 0:00:42
#    ---------- ----------------------------- 89.7/332.0 MB 5.7 MB/s eta 0:00:43
#    ---------- ----------------------------- 90.2/332.0 MB 5.6 MB/s eta 0:00:43
#    ---------- ----------------------------- 91.2/332.0 MB 5.6 MB/s eta 0:00:43
#    ----------- ---------------------------- 92.8/332.0 MB 5.6 MB/s eta 0:00:43
#    ----------- ---------------------------- 94.4/332.0 MB 5.7 MB/s eta 0:00:42
#    ----------- ---------------------------- 96.7/332.0 MB 5.7 MB/s eta 0:00:42
#    ----------- ---------------------------- 98.8/332.0 MB 5.8 MB/s eta 0:00:41
#    ------------ --------------------------- 99.9/332.0 MB 5.8 MB/s eta 0:00:41
#    ------------ --------------------------- 101.2/332.0 MB 5.8 MB/s eta 0:00:40
#    ------------ --------------------------- 102.2/332.0 MB 5.8 MB/s eta 0:00:40
#    ------------ --------------------------- 103.3/332.0 MB 5.8 MB/s eta 0:00:40
#    ------------ --------------------------- 104.3/332.0 MB 5.8 MB/s eta 0:00:40
#    ------------ --------------------------- 105.4/332.0 MB 5.7 MB/s eta 0:00:40
#    ------------ --------------------------- 106.2/332.0 MB 5.7 MB/s eta 0:00:40
#    ------------ --------------------------- 107.0/332.0 MB 5.7 MB/s eta 0:00:40
#    ------------ --------------------------- 107.7/332.0 MB 5.7 MB/s eta 0:00:40
#    ------------- -------------------------- 108.5/332.0 MB 5.7 MB/s eta 0:00:40
#    ------------- -------------------------- 110.1/332.0 MB 5.7 MB/s eta 0:00:40
#    ------------- -------------------------- 111.4/332.0 MB 5.7 MB/s eta 0:00:39
#    ------------- -------------------------- 111.7/332.0 MB 5.6 MB/s eta 0:00:40
#    ------------- -------------------------- 111.7/332.0 MB 5.6 MB/s eta 0:00:40
#    ------------- -------------------------- 112.2/332.0 MB 5.6 MB/s eta 0:00:40
#    ------------- -------------------------- 112.7/332.0 MB 5.5 MB/s eta 0:00:40
#    ------------- -------------------------- 113.8/332.0 MB 5.5 MB/s eta 0:00:40
#    ------------- -------------------------- 115.1/332.0 MB 5.5 MB/s eta 0:00:40
#    ------------- -------------------------- 116.1/332.0 MB 5.5 MB/s eta 0:00:40
#    -------------- ------------------------- 116.7/332.0 MB 5.5 MB/s eta 0:00:40
#    -------------- ------------------------- 117.4/332.0 MB 5.5 MB/s eta 0:00:40
#    -------------- ------------------------- 118.2/332.0 MB 5.4 MB/s eta 0:00:40
#    -------------- ------------------------- 119.0/332.0 MB 5.4 MB/s eta 0:00:40
#    -------------- ------------------------- 119.0/332.0 MB 5.4 MB/s eta 0:00:40
#    -------------- ------------------------- 119.0/332.0 MB 5.4 MB/s eta 0:00:40
#    -------------- ------------------------- 119.0/332.0 MB 5.4 MB/s eta 0:00:40
#    -------------- ------------------------- 119.5/332.0 MB 5.2 MB/s eta 0:00:41
#    -------------- ------------------------- 120.3/332.0 MB 5.2 MB/s eta 0:00:41
#    -------------- ------------------------- 121.4/332.0 MB 5.2 MB/s eta 0:00:41
#    -------------- ------------------------- 122.2/332.0 MB 5.2 MB/s eta 0:00:41
#    -------------- ------------------------- 122.9/332.0 MB 5.2 MB/s eta 0:00:41
#    -------------- ------------------------- 123.2/332.0 MB 5.2 MB/s eta 0:00:41
#    -------------- ------------------------- 123.7/332.0 MB 5.2 MB/s eta 0:00:41
#    --------------- ------------------------ 124.5/332.0 MB 5.1 MB/s eta 0:00:41
#    --------------- ------------------------ 125.3/332.0 MB 5.1 MB/s eta 0:00:41
#    --------------- ------------------------ 126.9/332.0 MB 5.1 MB/s eta 0:00:40
#    --------------- ------------------------ 128.5/332.0 MB 5.2 MB/s eta 0:00:40
#    --------------- ------------------------ 130.5/332.0 MB 5.2 MB/s eta 0:00:39
#    --------------- ------------------------ 131.9/332.0 MB 5.2 MB/s eta 0:00:39
#    ---------------- ----------------------- 132.9/332.0 MB 5.2 MB/s eta 0:00:39
#    ---------------- ----------------------- 134.2/332.0 MB 5.2 MB/s eta 0:00:38
#    ---------------- ----------------------- 135.8/332.0 MB 5.2 MB/s eta 0:00:38
#    ---------------- ----------------------- 136.8/332.0 MB 5.2 MB/s eta 0:00:38
#    ---------------- ----------------------- 137.9/332.0 MB 5.2 MB/s eta 0:00:38
#    ---------------- -----------------------
MB 1.9 MB/s eta 0:00:04
#    ---------------------------------------  327.2/332.0 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------------  328.2/332.0 MB 2.1 MB/s eta 0:00:02
#    ---------------------------------------  329.5/332.0 MB 2.1 MB/s eta 0:00:02
#    ---------------------------------------  331.4/332.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  331.9/332.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  331.9/332.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  331.9/332.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 332.0/332.0 MB 2.1 MB/s  0:01:48
# Installing collected packages: tensorflow-cpu
# Successfully installed tensorflow-cpu-2.20.0rc0
# Note: you may need to restart the kernel to use updated packages.

# %%
for i in label:
    #os.mkdir(dest_dir +  str(i) + "/")
    sample = skin_df2[skin_df2['dx'] == i]['image_id']
    label_images.extend(sample)
    for id in label_images:
        shutil.copyfile((data_dir + "/" + id + ".jpg"), (dest_dir + i + "/" + id + ".jpg"))
    label_images = []

# %%
#pip install keras

# %%
#pip install tensorflow

# %%
#python --version

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %%
datagen = ImageDataGenerator()

# %%
train_dir = os.getcwd() + "/HAM10000_dataset/recognised/"

# %%
train_data_keras = datagen.flow_from_directory(directory = train_dir, class_mode = 'categorical', batch_size = 16, target_size = (32, 32))
# Out:
# Found 10015 images belonging to 7 classes.

# %%
x, y = next(train_data_keras)

# %%
for i in range (0, 15):
    image = x[i].astype(int)
    plt.imshow(image)
    plt.show()

# %%
pip install torchvision
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torchvision
#   Downloading torchvision-0.23.0-cp313-cp313-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy in c:\users\prade\appdata\roaming\python\python313\site-packages (from torchvision) (2.3.2)
# Requirement already satisfied: torch==2.8.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from torchvision) (2.8.0+cpu)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in c:\users\prade\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\prade\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (1.13.3)
# Requirement already satisfied: networkx in c:\users\prade\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (3.3)
# Requirement already satisfied: jinja2 in c:\users\prade\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\prade\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\prade\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch==2.8.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from jinja2->torch==2.8.0->torchvision) (3.0.2)
# Downloading torchvision-0.23.0-cp313-cp313-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 10.1 MB/s  0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torchvision

# %%
print(torchvision.__version__)
# Out:
# 0.23.0+cpu

# %%
from torchvision import transforms

# %%
import torch.utils.data as data

# %%
train_dir = os.getcwd() + "/HAM10000_dataset/recognised/"

# %%
TRANSFORM_IMG = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean = [0.5, 0.5, 0.5],
                        std = [0.5, 0.5, 0.5])
])

# %%
train_data_torch = torchvision.datasets.ImageFolder(root = train_dir)

# %%
print("no. of train samples: ", len(train_data_torch))
print("detected classes are: ", train_data_torch.class_to_idx)
# Out:
# no. of train samples:  10015
# detected classes are:  {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
labels = np.array(train_data_torch.targets)
(unique, counts) = np.unique(labels, return_counts = True)
frequencies = np.asarray((unique, counts)).T
print(frequencies)
# Out:
# [[   0  327]
#  [   1  514]
#  [   2 1099]
#  [   3  115]
#  [   4 1113]
#  [   5 6705]
#  [   6  142]]

# %%
skin_df2
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\prade\appdata\roaming\python\python313\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\prade\appdata\roaming\python\python313\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\prade\appdata\roaming\python\python313\site-packages (from seaborn) (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prade\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prade\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prade\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\prade\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

# %%
from PIL import Image

# %%
np.random.seed(42)

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\prade\appdata\roaming\python\python313\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from scikit-learn) (2.3.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\prade\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn

# %%
from sklearn.metrics import confusion_matrix

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
import scipy
from scipy import stats

# %%
print(sns.__version__)
print(sklearn.__version__)
print(scipy.__version__)
# Out:
# 0.13.2
# 1.7.1
# 1.16.1

# %%
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#        label
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
# ...      ...
# 10010      0
# 10011      0
# 10012      0
# 10013      0
# 10014      4
#
# [10015 rows x 8 columns]

# %%
skin_df2
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
SIZE = 32

# %%
le = LabelEncoder()
le.fit(skin_df['dx'])
LabelEncoder()
print(list(le.classes_))
# Out:
# ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
skin_df['label'] = le.transform(skin_df["dx"])
print(skin_df.sample(10))
# Out:
#         lesion_id      image_id   dx    dx_type   age     sex  \
# 3697  HAM_0005218  ISIC_0028939   nv  follow_up  55.0  female
# 7213  HAM_0007444  ISIC_0033989   nv      histo  50.0  female
# 310   HAM_0002839  ISIC_0032280  bkl      histo  60.0  female
# 4438  HAM_0005070  ISIC_0030863   nv  follow_up  55.0  female
# 6087  HAM_0005969  ISIC_0028257   nv  follow_up  35.0    male
# 3586  HAM_0001464  ISIC_0028319   nv  follow_up  70.0    male
# 3733  HAM_0003513  ISIC_0030743   nv  follow_up  60.0    male
# 718   HAM_0001359  ISIC_0028628  bkl      histo  75.0    male
# 2090  HAM_0006006  ISIC_0028847  mel      histo  75.0    male
# 3417  HAM_0002741  ISIC_0027939   nv  follow_up  45.0  female
#
#          localization  label
# 3697  lower extremity      5
# 7213  lower extremity      5
# 310   lower extremity      2
# 4438            trunk      5
# 6087          abdomen      5
# 3586            trunk      5
# 3733  upper extremity      5
# 718   lower extremity      2
# 2090            chest      4
# 3417          abdomen      5

# %%
fig = plt.figure(figsize=(15,10))

# %%
ax1 = fig.add_subplot(221)
skin_df['dx'].value_counts().plot(kind = 'bar')
ax1.set_ylabel('Count')
ax1.set_title('Cell Type');

# %%
ax2 = fig.add_subplot(222)
skin_df['sex'].value_counts().plot(kind='bar')
ax2.set_ylabel('Count', size=15)
ax2.set_title('sex');

# %%
ax3 = fig.add_subplot(223)
skin_df['localization'].value_counts().plot(kind='bar')
ax3.set_ylabel('Count', size=12)
ax3.set_title('Localization');

# %%
skin_df2
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
ax4 = fig.add_subplot(224)
sample_age = skin_df[pd.notnull(skin_df['age'])]
sns.distplot(sample_age['age'], fit=stats.norm, color='red')
ax4.set_title('Age');
# Out:
# C:\Users\prade\AppData\Local\Temp\ipykernel_12956\2365755778.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_age['age'], fit=stats.norm, color='red')

# %%
plt.tight_layout()
plt.show()

# %%
from sklearn.utils import resample
print(skin_df['label'].value_counts())
# Out:
# label
# 5    6705
# 4    1113
# 2    1099
# 1     514
# 0     327
# 6     142
# 3     115
# Name: count, dtype: int64

# %%
df_0 = skin_df[skin_df['label'] == 0]
df_1 = skin_df[skin_df['label'] == 1]
df_2 = skin_df[skin_df['label'] == 2]
df_3 = skin_df[skin_df['label'] == 3]
df_4 = skin_df[skin_df['label'] == 4]
df_5 = skin_df[skin_df['label'] == 5]
df_6 = skin_df[skin_df['label'] == 6]

# %%
n_samples=500
df_0_balanced = resample(df_0, replace=True, n_samples=n_samples, random_state=42)
df_1_balanced = resample(df_1, replace=True, n_samples=n_samples, random_state=42)
df_2_balanced = resample(df_2, replace=True, n_samples=n_samples, random_state=42)
df_3_balanced = resample(df_3, replace=True, n_samples=n_samples, random_state=42)
df_4_balanced = resample(df_4, replace=True, n_samples=n_samples, random_state=42)
df_5_balanced = resample(df_5, replace=True, n_samples=n_samples, random_state=42)
df_6_balanced = resample(df_6, replace=True, n_samples=n_samples, random_state=42)

# %%
skin_df_balanced = pd.concat([
    df_0_balanced, df_1_balanced, df_2_balanced, df_3_balanced,
    df_4_balanced, df_5_balanced, df_6_balanced,
])

print(skin_df_balanced['label'].value_counts())
# Out:
# label
# 0    500
# 1    500
# 2    500
# 3    500
# 4    500
# 5    500
# 6    500
# Name: count, dtype: int64

# %%
image_path = {
    os.path.splitext(os.path.basename(x))[0]: x
        for x in glob(os.path.join('HAM10000_dataset/', '*', '*.jpg'))
}

# %%
skin_df_balanced['path'] = skin_df['image_id'].map(image_path.get)

# %%
skin_df_balanced['image'] = skin_df_balanced['path'].map(lambda x: np.asarray(Image.open(x).resize((SIZE, SIZE))))

# %%
print(np.__version__)
import tensorflow as tf
# Out:
# 2.3.2

# %%
x = np.asarray(skin_df_balanced['image'].tolist())
x = x/255
y = skin_df_balanced['label']
y_cat = to_categorical(y, num_classes=7)

x_train, x_test, y_train, y_test = train_test_split(x, y_cat, test_size=0.25, random_state= 42)

# %%
num_classes = 7

# %%
model = Sequential()
model.add(Conv2D(256, (3,3), activation="relu", input_shape=(SIZE, SIZE, 3)))
# Out:
# C:\Users\prade\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

# %%
model.add(Conv2D(128,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(32))
model.add(Dense(7,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 30, 30, 256)    │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 15, 15, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 15, 15, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 13, 13, 128)    │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 64)       │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         8,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 384,455 (1.47 MB)
#  Trainable params: 384,455 (1.47 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['acc'])

# %%
batch_size=16
epochs=50
history= model.fit(
    x_train,y_train,
    epochs=epochs,
    batch_size= batch_size,
    validation_data=(x_test,y_test),
    verbose=2)
score=model.evaluate(x_test, y_test)
print('Test accuracy:',score[1])
# Out:
# Epoch 1/50
# 165/165 - 8s - 50ms/step - acc: 0.1874 - loss: 1.8781 - val_acc: 0.2389 - val_loss: 1.7976
# Epoch 2/50
# 165/165 - 7s - 40ms/step - acc: 0.2545 - loss: 1.7673 - val_acc: 0.2640 - val_loss: 1.7611
# Epoch 3/50
# 165/165 - 7s - 40ms/step - acc: 0.3451 - loss: 1.6194 - val_acc: 0.3737 - val_loss: 1.5559
# Epoch 4/50
# 165/165 - 7s - 39ms/step - acc: 0.4137 - loss: 1.4672 - val_acc: 0.4354 - val_loss: 1.4024
# Epoch 5/50
# 165/165 - 7s - 40ms/step - acc: 0.4217 - loss: 1.4290 - val_acc: 0.3246 - val_loss: 1.6696
# Epoch 6/50
# 165/165 - 6s - 39ms/step - acc: 0.4636 - loss: 1.3658 - val_acc: 0.4503 - val_loss: 1.3298
# Epoch 7/50
# 165/165 - 7s - 39ms/step - acc: 0.4731 - loss: 1.3138 - val_acc: 0.4606 - val_loss: 1.3646
# Epoch 8/50
# 165/165 - 6s - 39ms/step - acc: 0.4872 - loss: 1.3006 - val_acc: 0.4766 - val_loss: 1.2587
# Epoch 9/50
# 165/165 - 6s - 39ms/step - acc: 0.5097 - loss: 1.2539 - val_acc: 0.5223 - val_loss: 1.2526
# Epoch 10/50
# 165/165 - 7s - 39ms/step - acc: 0.5025 - loss: 1.2645 - val_acc: 0.5360 - val_loss: 1.2130
# Epoch 11/50
# 165/165 - 6s - 39ms/step - acc: 0.5131 - loss: 1.2252 - val_acc: 0.5371 - val_loss: 1.1951
# Epoch 12/50
# 165/165 - 7s - 40ms/step - acc: 0.5257 - loss: 1.1872 - val_acc: 0.5280 - val_loss: 1.1799
# Epoch 13/50
# 165/165 - 6s - 39ms/step - acc: 0.5379 - loss: 1.1838 - val_acc: 0.5086 - val_loss: 1.1910
# Epoch 14/50
# 165/165 - 7s - 39ms/step - acc: 0.5288 - loss: 1.1448 - val_acc: 0.5520 - val_loss: 1.1472
# Epoch 15/50
# 165/165 - 6s - 39ms/step - acc: 0.5493 - loss: 1.1632 - val_acc: 0.5806 - val_loss: 1.1033
# Epoch 16/50
# 165/165 - 7s - 40ms/step - acc: 0.5810 - loss: 1.1047 - val_acc: 0.5234 - val_loss: 1.1993
# Epoch 17/50
# 165/165 - 7s - 40ms/step - acc: 0.5539 - loss: 1.1234 - val_acc: 0.5760 - val_loss: 1.1265
# Epoch 18/50
# 165/165 - 6s - 39ms/step - acc: 0.5756 - loss: 1.0921 - val_acc: 0.5531 - val_loss: 1.1757
# Epoch 19/50
# 165/165 - 6s - 39ms/step - acc: 0.5916 - loss: 1.0615 - val_acc: 0.5977 - val_loss: 1.0590
# Epoch 20/50
# 165/165 - 7s - 40ms/step - acc: 0.5810 - loss: 1.0723 - val_acc: 0.6046 - val_loss: 1.0484
# Epoch 21/50
# 165/165 - 7s - 39ms/step - acc: 0.6110 - loss: 1.0117 - val_acc: 0.5931 - val_loss: 1.0548
# Epoch 22/50
# 165/165 - 6s - 39ms/step - acc: 0.6065 - loss: 1.0106 - val_acc: 0.6297 - val_loss: 0.9976
# Epoch 23/50
# 165/165 - 6s - 39ms/step - acc: 0.6114 - loss: 1.0092 - val_acc: 0.6114 - val_loss: 1.0140
# Epoch 24/50
# 165/165 - 6s - 39ms/step - acc: 0.6263 - loss: 0.9612 - val_acc: 0.6080 - val_loss: 1.0403
# Epoch 25/50
# 165/165 - 6s - 39ms/step - acc: 0.6297 - loss: 0.9656 - val_acc: 0.6434 - val_loss: 0.9870
# Epoch 26/50
# 165/165 - 6s - 39ms/step - acc: 0.6278 - loss: 0.9605 - val_acc: 0.6160 - val_loss: 1.0180
# Epoch 27/50
# 165/165 - 6s - 39ms/step - acc: 0.6293 - loss: 0.9361 - val_acc: 0.6526 - val_loss: 0.9610
# Epoch 28/50
# 165/165 - 6s - 39ms/step - acc: 0.6423 - loss: 0.9348 - val_acc: 0.6560 - val_loss: 0.9408
# Epoch 29/50
# 165/165 - 7s - 40ms/step - acc: 0.6408 - loss: 0.9481 - val_acc: 0.6537 - val_loss: 0.9661
# Epoch 30/50
# 165/165 - 6s - 39ms/step - acc: 0.6373 - loss: 0.9418 - val_acc: 0.6560 - val_loss: 0.9791
# Epoch 31/50
# 165/165 - 6s - 39ms/step - acc: 0.6549 - loss: 0.8987 - val_acc: 0.6731 - val_loss: 0.9377
# Epoch 32/50
# 165/165 - 7s - 39ms/step - acc: 0.6469 - loss: 0.8936 - val_acc: 0.6629 - val_loss: 0.9336
# Epoch 33/50
# 165/165 - 6s - 39ms/step - acc: 0.6712 - loss: 0.8370 - val_acc: 0.6869 - val_loss: 0.9091
# Epoch 34/50
# 165/165 - 6s - 39ms/step - acc: 0.6716 - loss: 0.8491 - val_acc: 0.6949 - val_loss: 0.8899
# Epoch 35/50
# 165/165 - 7s - 40ms/step - acc: 0.6808 - loss: 0.8330 - val_acc: 0.6743 - val_loss: 0.9162
# Epoch 36/50
# 165/165 - 6s - 39ms/step - acc: 0.6899 - loss: 0.8125 - val_acc: 0.6789 - val_loss: 0.9296
# Epoch 37/50
# 165/165 - 7s - 40ms/step - acc: 0.6952 - loss: 0.7970 - val_acc: 0.6857 - val_loss: 0.9209
# Epoch 38/50
# 165/165 - 7s - 40ms/step - acc: 0.6690 - loss: 0.8565 - val_acc: 0.6869 - val_loss: 0.9094
# Epoch 39/50
# 165/165 - 6s - 39ms/step - acc: 0.7029 - loss: 0.7747 - val_acc: 0.6789 - val_loss: 0.8960
# Epoch 40/50
# 165/165 - 7s - 40ms/step - acc: 0.6910 - loss: 0.7906 - val_acc: 0.7006 - val_loss: 0.8576
# Epoch 41/50
# 165/165 - 7s - 40ms/step - acc: 0.7078 - loss: 0.7776 - val_acc: 0.6766 - val_loss: 0.9211
# Epoch 42/50
# 165/165 - 7s - 39ms/step - acc: 0.7150 - loss: 0.7613 - val_acc: 0.7257 - val_loss: 0.8173
# Epoch 43/50
# 165/165 - 6s - 39ms/step - acc: 0.7158 - loss: 0.7710 - val_acc: 0.7006 - val_loss: 0.8625
# Epoch 44/50
# 165/165 - 6s - 39ms/step - acc: 0.6990 - loss: 0.8031 - val_acc: 0.7314 - val_loss: 0.8156
# Epoch 45/50
# 165/165 - 7s - 39ms/step - acc: 0.7109 - loss: 0.7543 - val_acc: 0.6880 - val_loss: 0.8872
# Epoch 46/50
# 165/165 - 7s - 41ms/step - acc: 0.6682 - loss: 0.8818 - val_acc: 0.6960 - val_loss: 0.8758
# Epoch 47/50
# 165/165 - 7s - 40ms/step - acc: 0.7250 - loss: 0.7378 - val_acc: 0.7269 - val_loss: 0.8313
# Epoch 48/50
# 165/165 - 6s - 39ms/step - acc: 0.7040 - loss: 0.7536 - val_acc: 0.7086 - val_loss: 0.8278
# Epoch 49/50
# 165/165 - 7s - 40ms/step - acc: 0.7211 - loss: 0.7265 - val_acc: 0.7497 - val_loss: 0.8022
# Epoch 50/50
# 165/165 - 6s - 39ms/step - acc: 0.7307 - loss: 0.7126 - val_acc: 0.6834 - val_loss: 0.9337
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - acc: 0.6834 - loss: 0.9337
# Test accuracy: 0.6834285855293274

# %%
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#        label
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
# ...      ...
# 10010      0
# 10011      0
# 10012      0
# 10013      0
# 10014      4
#
# [10015 rows x 8 columns]

# %%
import pickle

# %%
import sys
print(sys.version)
# Out:
# 3.13.3 (tags/v3.13.3:6280bb5, Apr  8 2025, 14:47:33) [MSC v.1943 64 bit (AMD64)]

# %%
pickle_out = open("skin_cancer_model-0.1.0.pkl", "wb")
pickle.dump(model, pickle_out)
pickle_out.close()

# %%
pip show requests
# Out:
# Name: requests
# Version: 2.32.4
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\prade\AppData\Roaming\Python\Python313\site-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by: jupyterlab_server, kagglehub, tensorflow, tensorflow_cpu
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install importlib-metadata
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting importlib-metadata
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, importlib-metadata
#
#    -------------------- ------------------- 1/2 [importlib-metadata]
#    ---------------------------------------- 2/2 [importlib-metadata]
#
# Successfully installed importlib-metadata-8.7.0 zipp-3.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from importlib_metadata import version
print(version("requests"))
# Out:
# 2.32.4

# %%
print(np.__version__)
# Out:
# 2.3.2
